# %%
import numpy as np
from matplotlib import pyplot as plt

plt.ion()

eprewards = np.load("episode_rewards.npz")['payload']
losses = np.load("losses.npz")['payload']

plt.plot(losses)
plt.show(block=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-ed5eaa668c5f> in <module>
#       8
#       9 plt.plot(losses)
# ---> 10 plt.show(block=True, figsize=(20,20))
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     252     """
#     253     global _show
# --> 254     return _show(*args, **kw)
#     255
#     256
#
# TypeError: show() got an unexpected keyword argument 'figsize'
