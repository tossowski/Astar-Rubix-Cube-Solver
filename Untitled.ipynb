# %%
import numpy as np
from matplotlib import pyplot as plt

plt.ion()

eprewards = np.load("episode_rewards.npz")['payload']
losses = np.load("losses.npz")['payload']


plt.figure(figsize=(20,10))
plt.plot(losses)
plt.show(block=True)
